# %%
## Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
## Loading dataset as a dataframe
data=pd.read_csv('iris.csv')

# %%
## Top 5 rows of the dataset
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
## Basic Info about data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
## Statstics about data
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
## Checking for the null values
data.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# Task1: Feature and datatypes
data.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
# Task2: Histograms
data.hist(figsize=(10,8),bins=20)
plt.suptitle("Histograms")
plt.show()

# %%
## Outliers
sns.histplot(data['SepalLengthCm'],bins=20)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
# Outliers
sns.histplot(data['SepalWidthCm'],bins=20)
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Count'>

# %%
# Outliers
sns.histplot(data['PetalLengthCm'],bins=20)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>

# %%
# Outliers
sns.histplot(data['PetalWidthCm'],bins=20)
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Count'>

# %%
# Distribution according to Petal Length
sns.boxplot(x="Species", y="PetalLengthCm", data=data)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
# Distribution According Petal Width
sns.boxplot(x="Species", y="PetalWidthCm", data=data)
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>

# %%
# Distribution According Sepal Length
sns.boxplot(x="Species", y="SepalLengthCm", data=data)
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
# Distribution According Sepal Width
sns.boxplot(x="Species", y="SepalWidthCm", data=data)
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
# Correlation among data
sns.heatmap(data[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']].corr(),annot=True)
# Out:
# <Axes: >
