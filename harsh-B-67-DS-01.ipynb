# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Reading Dataset
df=pd.read_csv('dataset_FIFA.csv')
print(df.to_string())
# Out:
#     ID  Year        Date           Stage      Home Team      Away Team Host Team
# 0    1  2022  2022-11-20     Group stage          Qatar        Ecuador      True
# 1    2  2022  2022-11-21     Group stage        Senegal    Netherlands     False
# 2    3  2022  2022-11-21     Group stage        England           Iran     False
# 3    4  2022  2022-11-21     Group stage  United States          Wales     False
# 4    5  2022  2022-11-22     Group stage         France      Australia     False
# 5    6  2022  2022-11-22     Group stage        Denmark        Tunisia     False
# 6    7  2022  2022-11-22     Group stage         Mexico         Poland     False
# 7    8  2022  2022-11-22     Group stage      Argentina   Saudi Arabia     False
# 8    9  2022  2022-11-23     Group stage        Belgium         Canada     False
# 9   10  2022  2022-11-23     Group stage          Spain     Costa Rica     False
# 10  11  2022  2022-11-23     Group stage        Germany          Japan     False
# ...

# %%
#.info() to get overview of data
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         64 non-null     int64
#  1   Year       64 non-null     int64
#  2   Date       64 non-null     object
#  3   Stage      64 non-null     object
#  4   Home Team  64 non-null     object
#  5   Away Team  64 non-null     object
#  6   Host Team  48 non-null     object
# dtypes: int64(2), object(5)
# memory usage: 3.6+ KB
# None

# %%
#To get basic statstical information about dataset
df.describe()
# Out:
#               ID    Year
# count  64.000000    64.0
# mean   32.500000  2022.0
# std    18.618987     0.0
# min     1.000000  2022.0
# 25%    16.750000  2022.0
# 50%    32.500000  2022.0
# 75%    48.250000  2022.0
# max    64.000000  2022.0

# %%
#Converting Dataframe into numpy array
numpy_array=df.to_numpy()

# %%
df.head()
# Out:
#    ID  Year        Date        Stage      Home Team    Away Team Host Team
# 0   1  2022  2022-11-20  Group stage          Qatar      Ecuador      True
# 1   2  2022  2022-11-21  Group stage        Senegal  Netherlands     False
# 2   3  2022  2022-11-21  Group stage        England         Iran     False
# 3   4  2022  2022-11-21  Group stage  United States        Wales     False
# 4   5  2022  2022-11-22  Group stage         France    Australia     False

# %%
#To Check for null values
df.isna()
# Out:
#        ID   Year   Date  Stage  Home Team  Away Team  Host Team
# 0   False  False  False  False      False      False      False
# 1   False  False  False  False      False      False      False
# 2   False  False  False  False      False      False      False
# 3   False  False  False  False      False      False      False
# 4   False  False  False  False      False      False      False
# ..    ...    ...    ...    ...        ...        ...        ...
# 59  False  False  False  False      False      False       True
# 60  False  False  False  False      False      False       True
# 61  False  False  False  False      False      False       True
# 62  False  False  False  False      False      False       True
# 63  False  False  False  False      False      False       True
#
# [64 rows x 7 columns]

# %%
#dropping columns
#inplace is used to make changes on original dataset
new_df=df.drop(['Year','Date'],axis=1)

# %%
#to_string() method prints the whole dataframe at once because it treats the dataset as string
print(new_df.to_string())
# Out:
#     ID           Stage      Home Team      Away Team Host Team
# 0    1     Group stage          Qatar        Ecuador      True
# 1    2     Group stage        Senegal    Netherlands     False
# 2    3     Group stage        England           Iran     False
# 3    4     Group stage  United States          Wales     False
# 4    5     Group stage         France      Australia     False
# 5    6     Group stage        Denmark        Tunisia     False
# 6    7     Group stage         Mexico         Poland     False
# 7    8     Group stage      Argentina   Saudi Arabia     False
# 8    9     Group stage        Belgium         Canada     False
# 9   10     Group stage          Spain     Costa Rica     False
# 10  11     Group stage        Germany          Japan     False
# 11  12     Group stage        Morocco        Croatia     False
# 12  13     Group stage    Switzerland       Cameroon     False
# 13  14     Group stage        Uruguay    South Korea     False
# ...

# %%
#Printing selected rows from the dataframe
df[['Year','Date']]
# Out:
#     Year        Date
# 0   2022  2022-11-20
# 1   2022  2022-11-21
# 2   2022  2022-11-21
# 3   2022  2022-11-21
# 4   2022  2022-11-22
# ..   ...         ...
# 59  2022  2022-12-10
# 60  2022  2022-12-13
# 61  2022  2022-12-14
# 62  2022  2022-12-17
# 63  2022  2022-12-18
#
# [64 rows x 2 columns]

# %%
#Data types of all the columns
df.dtypes
# Out:
# ID            int64
# Year          int64
# Date         object
# Stage        object
# Home Team    object
# Away Team    object
# Host Team    object
# dtype: object

# %%
#Shape of the dataframe
df.shape
# Out:
# (64, 7)

# %%
#to plot histogram
df.hist()
# Out:
# array([[<Axes: title={'center': 'ID'}>, <Axes: title={'center': 'Year'}>]],
#       dtype=object)

# %%
#to find null values
df.isnull()
# Out:
#        ID   Year   Date  Stage  Home Team  Away Team  Host Team
# 0   False  False  False  False      False      False      False
# 1   False  False  False  False      False      False      False
# 2   False  False  False  False      False      False      False
# 3   False  False  False  False      False      False      False
# 4   False  False  False  False      False      False      False
# ..    ...    ...    ...    ...        ...        ...        ...
# 59  False  False  False  False      False      False       True
# 60  False  False  False  False      False      False       True
# 61  False  False  False  False      False      False       True
# 62  False  False  False  False      False      False       True
# 63  False  False  False  False      False      False       True
#
# [64 rows x 7 columns]

# %%
#to drop duplicate values
new_df=df.dropna()

# %%
print(new_df)
# Out:
#     ID  Year        Date        Stage      Home Team      Away Team Host Team
# 0    1  2022  2022-11-20  Group stage          Qatar        Ecuador      True
# 1    2  2022  2022-11-21  Group stage        Senegal    Netherlands     False
# 2    3  2022  2022-11-21  Group stage        England           Iran     False
# 3    4  2022  2022-11-21  Group stage  United States          Wales     False
# 4    5  2022  2022-11-22  Group stage         France      Australia     False
# 5    6  2022  2022-11-22  Group stage        Denmark        Tunisia     False
# 6    7  2022  2022-11-22  Group stage         Mexico         Poland     False
# 7    8  2022  2022-11-22  Group stage      Argentina   Saudi Arabia     False
# 8    9  2022  2022-11-23  Group stage        Belgium         Canada     False
# 9   10  2022  2022-11-23  Group stage          Spain     Costa Rica     False
# 10  11  2022  2022-11-23  Group stage        Germany          Japan     False
# ...
